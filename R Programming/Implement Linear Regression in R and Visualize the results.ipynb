# %% [markdown]
# # Linear Regression In R

# %% [markdown]
# * load the car data using data() and see what it contains

# %%
# Load the 'cars' dataset
data(cars)

# View the dataset
View(cars)
# Out:
#    speed dist
# 1   4      2
# 2   4     10
# 3   7      4
# 4   7     22
# 5   8     16
# 6   9     10
# 7  10     18
# 8  10     26
# 9  10     34
# 10 11     17
# 11 11     28
# 12 12     14
# 13 12     20
# 14 12     24
# 15 12     28
# 16 13     26
# 17 13     34
# 18 13     34
# 19 13     46
# 20 14     26
# 21 14     36
# 22 14     60
# 23 14     80
# 24 15     20
# 25 15     26
# 26 15     54
# 27 16     32
# 28 16     40
# 29 17     32
# 30 17     40
# 31 17     50
# 32 18     42
# 33 18     56
# 34 18     76
# 35 18     84
# 36 19     36
# 37 19     46
# 38 19     68
# 39 20     32
# 40 20     48
# 41 20     52
# 42 20     56
# 43 20     64
# 44 22     66
# 45 23     54
# 46 24     70
# 47 24     92
# 48 24     93
# 49 24    120
# 50 25     85

# %% [markdown]
# # Visualization and Training the Model

# %%
install.packages('caTools')
library(caTools)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# we will train a model of the form Y = β1 + β2X + ε where Y is the car breaking distance and X is the car's speed. To train a linear model on the data, we use the lm() command.

# %%
split = sample.split(cars$dist, SplitRatio = 0.7)
trainingset = subset(cars, split == TRUE)
testset = subset(cars, split == FALSE)

# Fitting Simple Linear Regression to the Training set
model = lm(formula = cars$dist ~ cars$speed)

# %%
# Display a summary of the linear regression model
summary(model)
# Out:
# Call:
# lm(formula = cars$dist ~ cars$speed)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -29.069  -9.525  -2.272   9.215  43.201
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -17.5791     6.7584  -2.601   0.0123 *
# cars$speed    3.9324     0.4155   9.464 1.49e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 15.38 on 48 degrees of freedom
# Multiple R-squared:  0.6511,	Adjusted R-squared:  0.6438
# F-statistic: 89.57 on 1 and 48 DF,  p-value: 1.49e-12

# %% [markdown]
# We now have a trained linear model that predicts the stopping distance of a car given its speed.

# %% [markdown]
# Regression Line : Distance  = -17.58+3.93*Speed

# %% [markdown]
# To visualize our regression line, we can overlay it with the original training data.

# %%
# Create a scatter plot of 'dist' against 'speed'
plot(dist ~ speed, data = cars)

# Add the regression line to the plot in red color
abline(model, col = "red")
# Out:
# plot without title

# %% [markdown]
# To view additional details of the model, use the summary() command:

# %% [markdown]
#  summary provides lots of data on the model such as the R squared and adjusted R squared values, the F statistic, and the p-value and is a valuable tool for evaluating the model. Since p < 0.05, we can reject the null hypothesis.

# %% [markdown]
# We can also view other information such as the error sum of squares and mean sum of squares through the anova() command.

# %%
# Perform an analysis of variance (ANOVA) on the linear regression model
anova(model)
# Out:
#            Df Sum Sq   Mean Sq    F value  Pr(>F)
# cars$speed  1 21185.46 21185.4589 89.56711 1.489836e-12
# Residuals  48 11353.52   236.5317       NA           NA

# %% [markdown]
# Additionally, we can graphically analyze the statistical properties of our model.

# %%
# Plot diagnostic plots for the linear regression model
plot(model)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
